# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("ipl_all_seasons_ball_by_ball.csv")

# %%
df.head()
# Out:
#         ID  innings  overs  ballnumber       batter            name  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out dismissal_kind fielders_involved  \
# ...

# %%
df.drop(columns=['ID',],axis=1,inplace=True)

# %%
df.head()
# Out:
#    innings  overs  ballnumber       batter            name  non-striker  \
# 0        1      0           1  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1        1      0           2  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2        1      0           3   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3        1      0           4  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4        1      0           5  YBK Jaiswal  Mohammed Shami   JC Buttler
#
#   extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0        NaN            0           0          0             0
# 1    legbyes            0           1          1             0
# 2        NaN            1           0          1             0
# 3        NaN            0           0          0             0
# 4        NaN            0           0          0             0
#
#    isWicketDelivery player_out dismissal_kind fielders_involved  \
# 0                 0        NaN            NaN               NaN
# ...

# %%
df.describe()
# Out:
#              innings          overs     ballnumber    batsman_run  \
# count  225954.000000  225954.000000  225954.000000  225954.000000
# mean        1.483868       9.185679       3.619750       1.243523
# std         0.503104       5.681797       1.810633       1.618166
# min         1.000000       0.000000       1.000000       0.000000
# 25%         1.000000       4.000000       2.000000       0.000000
# 50%         1.000000       9.000000       4.000000       1.000000
# 75%         2.000000      14.000000       5.000000       1.000000
# max         6.000000      19.000000      10.000000       6.000000
#
#           extras_run     total_run   non_boundary  isWicketDelivery
# count  225954.000000  225954.00000  225954.000000     225954.000000
# mean        0.066907       1.31043       0.000093          0.049351
# std         0.341470       1.60605       0.009640          0.216600
# min         0.000000       0.00000       0.000000          0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   innings            225954 non-null  int64
#  1   overs              225954 non-null  int64
#  2   ballnumber         225954 non-null  int64
#  3   batter             225954 non-null  object
#  4   name               225954 non-null  object
#  5   non-striker        225954 non-null  object
#  6   extra_type         12049 non-null   object
#  7   batsman_run        225954 non-null  int64
#  8   extras_run         225954 non-null  int64
#  9   total_run          225954 non-null  int64
#  10  non_boundary       225954 non-null  int64
#  11  isWicketDelivery   225954 non-null  int64
#  12  player_out         11151 non-null   object
#  13  dismissal_kind     11151 non-null   object
#  14  fielders_involved  7988 non-null    object
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
url = 'https://stats.espncricinfo.com/ci/engine/records/bowling/most_wickets_career.html?id=117;type=trophy'

# %%
DF = pd.read_html(url)

# %%
New_df = pd.read_html(url)[0]

# %%
New_df
# Out:
#                                                Player  \
# 0                                            DJ Bravo
# 1   (Chennai Super Kings, Gujarat Lions, Mumbai In...
# 2                                           YS Chahal
# 3   (Mumbai Indians, Rajasthan Royals, Royal Chall...
# 4                                          SL Malinga
# ..                                                ...
# 95                                 (Rajasthan Royals)
# 96                                          JH Kallis
# 97  (Kolkata Knight Riders, Royal Challengers Bang...
# 98                                          KV Sharma
# 99  (Chennai Super Kings, Mumbai Indians, Royal Ch...
#
#                                                  Span  \
# 0                                           2008-2022
# 1   (Chennai Super Kings, Gujarat Lions, Mumbai In...
# 2                                           2013-2023
# 3   (Mumbai Indians, Rajasthan Royals, Royal Chall...
# ...

# %%
New_df.rename({'Player':'name'},axis=1,inplace=True)

# %%
merge_1 =  pd.merge(df,New_df,on='name')

# %%
merge_1
# Out:
#         innings  overs  ballnumber       batter            name  non-striker  \
# 0             1      0           1  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1             1      0           2  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2             1      0           3   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3             1      0           4  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4             1      0           5  YBK Jaiswal  Mohammed Shami   JC Buttler
# ...         ...    ...         ...          ...             ...          ...
# 108673        2     14           3     S Dhawan      SK Trivedi    G Gambhir
# 108674        2     14           4     S Dhawan      SK Trivedi    G Gambhir
# 108675        2     14           5     S Dhawan      SK Trivedi    G Gambhir
# 108676        2     14           6     S Dhawan      SK Trivedi    G Gambhir
# 108677        2     14           7    G Gambhir      SK Trivedi     S Dhawan
#
# ...

# %%
merge_1.columns
# Out:
# Index(['innings', 'overs', 'ballnumber', 'batter', 'name', 'non-striker',
#        'extra_type', 'batsman_run', 'extras_run', 'total_run', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'dismissal_kind', 'fielders_involved',
#        'BattingTeam', 'Span', 'Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts',
#        'BBI', 'Ave', 'Econ', 'SR', '4', '5'],
#       dtype='object')

# %%
merge_1.drop(columns=['Inns','Overs','Mdns','Runs','Wkts','BBI','Ave','Econ','SR','4','5'],axis=1,inplace = True)

# %%
merge_1.head()
# Out:
#    innings  overs  ballnumber       batter            name  non-striker  \
# 0        1      0           1  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1        1      0           2  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2        1      0           3   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3        1      0           4  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4        1      0           5  YBK Jaiswal  Mohammed Shami   JC Buttler
#
#   extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0        NaN            0           0          0             0
# 1    legbyes            0           1          1             0
# 2        NaN            1           0          1             0
# 3        NaN            0           0          0             0
# 4        NaN            0           0          0             0
#
#    isWicketDelivery player_out dismissal_kind fielders_involved  \
# 0                 0        NaN            NaN               NaN
# ...

# %%
merge_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108678 entries, 0 to 108677
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   innings            108678 non-null  int64
#  1   overs              108678 non-null  int64
#  2   ballnumber         108678 non-null  int64
#  3   batter             108678 non-null  object
#  4   name               108678 non-null  object
#  5   non-striker        108678 non-null  object
#  6   extra_type         5578 non-null    object
#  7   batsman_run        108678 non-null  int64
#  8   extras_run         108678 non-null  int64
#  9   total_run          108678 non-null  int64
#  10  non_boundary       108678 non-null  int64
#  11  isWicketDelivery   108678 non-null  int64
#  12  player_out         5608 non-null    object
#  13  dismissal_kind     5608 non-null    object
#  14  fielders_involved  3949 non-null    object
# ...

# %%
merge_1['name'].unique()
# Out:
# array(['Mohammed Shami', 'Rashid Khan', 'TA Boult', 'YS Chahal',
#        'R Ashwin', 'Mohammed Siraj', 'HV Patel', 'KH Pandya', 'K Rabada',
#        'B Kumar', 'JJ Bumrah', 'SN Thakur', 'Kuldeep Yadav', 'AR Patel',
#        'UT Yadav', 'SP Narine', 'AD Russell', 'DJ Bravo', 'KA Pollard',
#        'Sandeep Sharma', 'RA Jadeja', 'JD Unadkat', 'CH Morris',
#        'PP Chawla', 'I Sharma', 'DS Kulkarni', 'A Mishra', 'Imran Tahir',
#        'Harbhajan Singh', 'KV Sharma', 'DW Steyn', 'MM Sharma',
#        'MJ McClenaghan', 'SL Malinga', 'SR Watson', 'R Vinay Kumar',
#        'Z Khan', 'P Kumar', 'MM Patel', 'A Nehra', 'IK Pathan',
#        'AB Dinda', 'R Bhatia', 'M Morkel', 'RP Singh', 'JA Morkel',
#        'PP Ojha', 'L Balaji', 'JH Kallis', 'SK Trivedi'], dtype=object)

# %%
### Wickets taken by a particular bowler in a season
merge_1.head()
# Out:
#    innings  overs  ballnumber       batter            name  non-striker  \
# 0        1      0           1  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1        1      0           2  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2        1      0           3   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3        1      0           4  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4        1      0           5  YBK Jaiswal  Mohammed Shami   JC Buttler
#
#   extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0        NaN            0           0          0             0
# 1    legbyes            0           1          1             0
# 2        NaN            1           0          1             0
# 3        NaN            0           0          0             0
# 4        NaN            0           0          0             0
#
#    isWicketDelivery player_out dismissal_kind fielders_involved  \
# 0                 0        NaN            NaN               NaN
# ...

# %%
merge_1.corr()
# Out:
#                    innings     overs  ballnumber  batsman_run  extras_run  \
# innings           1.000000 -0.060408   -0.004351    -0.011998    0.000373
# overs            -0.060408  1.000000   -0.002145     0.088522    0.002119
# ballnumber       -0.004351 -0.002145    1.000000     0.003415    0.000484
# batsman_run      -0.011998  0.088522    0.003415     1.000000   -0.136230
# extras_run        0.000373  0.002119    0.000484    -0.136230    1.000000
# total_run        -0.011996  0.089546    0.003540     0.977369    0.076423
# non_boundary     -0.000530 -0.001838    0.000010     0.024380   -0.002097
# isWicketDelivery -0.000112  0.082472    0.007480    -0.172136   -0.041404
#
#                   total_run  non_boundary  isWicketDelivery
# innings           -0.011996     -0.000530         -0.000112
# overs              0.089546     -0.001838          0.082472
# ballnumber         0.003540      0.000010          0.007480
# batsman_run        0.977369      0.024380         -0.172136
# ...

# %%
sns.heatmap(merge_1.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='overs',y='isWicketDelivery',data=merge_1,kind='hex')

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.pairplot(merge_1)

# %%
sns.pairplot(merge_1,hue='name')

# %%
plt.bar(merge_1['isWicketDelivery'],merge_1['non_boundary'])
plt.xlabel('Wickets')
plt.ylabel('dot balls')
# Out:
# Text(0, 0.5, 'dot balls')

# %%
plt.boxplot(merge_1['isWicketDelivery'],vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dd77db3dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dd7c6ab040>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1dd77db3a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dd7c6ab940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dd7c6abc10>],
#  'means': []}

# %%
plt.hist(merge_1['total_run'])
plt.xlabel('total_run Conceded')
# Out:
# Text(0.5, 0, 'total_run Conceded')

# %%
merge_1.head()
# Out:
#    innings  overs  ballnumber       batter            name  non-striker  \
# 0        1      0           1  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1        1      0           2  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2        1      0           3   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3        1      0           4  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4        1      0           5  YBK Jaiswal  Mohammed Shami   JC Buttler
#
#   extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0        NaN            0           0          0             0
# 1    legbyes            0           1          1             0
# 2        NaN            1           0          1             0
# 3        NaN            0           0          0             0
# 4        NaN            0           0          0             0
#
#    isWicketDelivery player_out dismissal_kind fielders_involved  \
# 0                 0        NaN            NaN               NaN
# ...

# %%
merge_1[['name','total_run']]
# Out:
#                   name  total_run
# 0       Mohammed Shami          0
# 1       Mohammed Shami          1
# 2       Mohammed Shami          1
# 3       Mohammed Shami          0
# 4       Mohammed Shami          0
# ...                ...        ...
# 108673      SK Trivedi          4
# 108674      SK Trivedi          2
# 108675      SK Trivedi          4
# 108676      SK Trivedi          1
# 108677      SK Trivedi          0
#
# [108678 rows x 2 columns]

# %%
merge_1[(merge_1['name'] == 'UT Yadav') & (merge_1['isWicketDelivery'])]
# Out:
#        innings  overs  ballnumber           batter      name  \
# 31218        2     14           4       AK Markram  UT Yadav
# 31227        1      2           1       D Padikkal  UT Yadav
# 31247        2      0           1          PP Shaw  UT Yadav
# 31261        2      9           3        DA Warner  UT Yadav
# 31265        2     11           1          RR Pant  UT Yadav
# ...        ...    ...         ...              ...       ...
# 34032        2     13           4        DJ Hussey  UT Yadav
# 34037        2     15           2       AD Mathews  UT Yadav
# 34063        2     17           2          P Kumar  UT Yadav
# 34088        1     19           3  Y Venugopal Rao  UT Yadav
# 34104        2      6           7      S Badrinath  UT Yadav
#
#              non-striker extra_type  batsman_run  extras_run  total_run  \
# 31218  Washington Sundar        NaN            0           0          0
# 31227         JC Buttler        NaN            0           0          0
# ...

# %%
merge_1.to_csv('term_project_dataset.csv')

# %%
df=pd.read_csv("all_seasons_match_winners.csv")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Venue', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Season', hue='TossDecision', data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
merged_data = pd.merge(df, df,how='inner')

# %%
merged_data.head()
# Out:
#         ID       City       Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  5/29/2022   2022        Final
# 1  1312199  Ahmedabad  5/27/2022   2022  Qualifier 2
# 2  1312198    Kolkata  5/25/2022   2022   Eliminator
# 3  1312197    Kolkata  5/24/2022   2022  Qualifier 1
# 4  1304116     Mumbai  5/22/2022   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...
